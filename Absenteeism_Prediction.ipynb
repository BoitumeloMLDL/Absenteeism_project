# %% [markdown]
# # Absenteeism Project - Prediction Notebook

# %% [markdown]
# ### Importing the absenteeism_module

# %% [markdown]
# The module is to automate the process of data preprocessing, data splitting and grouping, data manipulation and predictive modelling of a new dataset containing similar information.

# %%
from absenteeism_module import *

# %% [markdown]
# #### Viewing the new dataset

# %%
pd.read_csv('Absenteeism_new_data.csv').head()
# Out:
#    ID  Reason for Absence        Date  Transportation Expense  \
# 0  22                  27  01/06/2018                     179
# 1  10                   7  04/06/2018                     361
# 2  14                  23  06/06/2018                     155
# 3  17                  25  08/06/2018                     179
# 4  14                  10  08/06/2018                     155
#
#    Distance to Work  Age  Daily Work Load Average  Body Mass Index  Education  \
# 0                26   30                  237.656               19          3
# 1                52   28                  237.656               27          1
# 2                12   34                  237.656               25          1
# 3                22   40                  237.656               22          2
# 4                12   34                  237.656               25          1
#
#    Children  Pets
# 0         0     0
# 1         1     4
# 2         2     0
# 3         2     0
# 4         2     0

# %% [markdown]
# #### Creating a Model object using the trained Logistic Regression model

# %%
model = absenteeism_model('model','scaler')

# %% [markdown]
# #### Using the model object to load and clean the dataset

# %%
model.load_and_clean_data('Absenteeism_new_data.csv')

# %% [markdown]
# #### Create a dataset with probability of prediction and prediction

# %%
model.predicted_outputs()
# Out:
#     Reason_1  Reason_2  Reason_3  Reason_4  Month Value  \
# 0          0       0.0         0         1            6
# 1          1       0.0         0         0            6
# 2          0       0.0         0         1            6
# 3          0       0.0         0         1            6
# 4          1       0.0         0         0            6
# 5          1       0.0         0         0            6
# 6          1       0.0         0         0            6
# 7          0       0.0         0         1            6
# 8          0       0.0         0         1            6
# 9          1       0.0         0         0            6
# 10         0       0.0         0         1            6
# 11         0       0.0         1         0            6
# 12         0       0.0         1         0            6
# 13         0       0.0         0         1            6
# 14         0       0.0         0         0            6
# 15         0       0.0         0         0            6
# ...

# %% [markdown]
# #### Create a csv file of prediction dataset

# %%
model.preprocessed_data.to_csv('Absenteeism_prediction.csv', index=False)
